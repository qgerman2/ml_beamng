# %%
from pathlib import Path
import pandas as pd
import numpy as np
from io import StringIO
from sklearn.preprocessing import MaxAbsScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from IPython.display import clear_output
from beamngpy import BeamNGpy, Scenario, Vehicle
from beamngpy.sensors import Electrics
import keyboard
import time

def millis():
    return time.time_ns() / 1000000
oldtime = millis()
curtime = 0
rectime = 0
step = 1/60 * 1000 #60 hz

# %% [markdown]
# ## Lectura de datos

# %%
# Leer carpeta
CARPETA = "automatico"
datos = False
columnas = [
    # Comandos
    "throttle",
    "brake",
    "clutch",
    "gear",
    # Estado
    "throttle_input",
    "brake_input",
    "rpm",
    "airspeed"
]
files = Path(CARPETA).glob('*')
for i, ruta in enumerate(files):
    df = pd.read_csv(ruta, usecols=columnas + ["is_shifting"])
    if (i == 0):
        datos = df
    else:
        datos = pd.concat([datos, df], ignore_index=True)
#mantener cambio
gear = 0
for i in range(datos.shape[0]):
    if (datos["is_shifting"].iloc[i] == True):
        if (datos["gear"].iloc[i] == 0):
            datos.at[i, "gear"] = gear
    else:
        gear = datos["gear"].iloc[i]
datos.drop(columns="is_shifting", inplace=True)
#aceleración
"""
accel = [0]
for i in range(datos.shape[0]):
    if i == 0:
        continue
    accel.append(datos["airspeed"].iloc[i] - datos["airspeed"].iloc[i-1])
datos["accel"] = accel
datos.drop(datos[datos["accel"]<-0.2].index, inplace=True)
"""
datos = datos[columnas]

# %% [markdown]
# ## Interpretación de comando

# %%
def stateToCmd(x):
    cmd = 0
    throttle = x["throttle_input"].iloc[0]
    brake = x["brake_input"].iloc[0]
    clutch = x["clutch_input"].iloc[0]
    speed = x["airspeed"].iloc[0]
    accel = x["accel"].iloc[0]
    rpm = x["rpm"].iloc[0]
    gear = x["gear"].iloc[0]
    if clutch > 0:
        if rpm >= 3500:
            cmd = 1
        elif rpm < 3500:
            if throttle > 0:
                cmd = 1
            elif accel < -0.01:
                cmd = -1
    else:
        if accel > 0.01:
            cmd = 1
        elif (accel < 0.01 and accel > -0.01):
            cmd = 0
        elif accel < -0.01:
            cmd = -1
    return cmd

# %%
cmds = []
for i in range(datos.shape[0]):
    cmds.append(stateToCmd(datos[i:i+1]))
datos["cmd"] = cmds
datos = datos[columnas+["accel","cmd"]]

# %% [markdown]
# ## Normalizar

# %%
scaler = MaxAbsScaler().fit(datos)
datos_scaled = pd.DataFrame(scaler.transform(datos), index=datos.index, columns=datos.columns)
display(datos)
display(datos_scaled)
# Out:
#        throttle  brake  clutch  gear  throttle_input  brake_input         rpm  \
# 0           0.0    0.3     1.0   1.0             0.0          0.0  677.650753
# 1           0.0    0.3     1.0   1.0             0.0          0.0  674.418942
# 2           0.0    0.3     1.0   1.0             0.0          0.0  677.589228
# 3           0.0    0.3     1.0   1.0             0.0          0.0  680.929954
# 4           0.0    0.3     1.0   1.0             0.0          0.0  677.760520
# ...         ...    ...     ...   ...             ...          ...         ...
# 26243       0.0    0.3     1.0   1.0             0.0          0.0  674.727744
# 26244       0.0    0.3     1.0   1.0             0.0          0.0  677.971016
# 26245       0.0    0.3     1.0   1.0             0.0          0.0  681.158786
# 26246       0.0    0.3     1.0   1.0             0.0          0.0  678.049100
# 26247       0.0    0.3     1.0   1.0             0.0          0.0  674.860924
#
#        airspeed
# 0      0.000130
# 1      0.000126
# 2      0.000147
# 3      0.000171
# 4      0.000180
# ...         ...
# 26243  0.011388
# 26244  0.009939
# 26245  0.009315
# 26246  0.009805
# 26247  0.009637
#
# [26248 rows x 8 columns]
#        throttle  brake  clutch  gear  throttle_input  brake_input       rpm  \
# 0           0.0    0.3     1.0   0.2             0.0          0.0  0.105539
# 1           0.0    0.3     1.0   0.2             0.0          0.0  0.105036
# 2           0.0    0.3     1.0   0.2             0.0          0.0  0.105530
# 3           0.0    0.3     1.0   0.2             0.0          0.0  0.106050
# 4           0.0    0.3     1.0   0.2             0.0          0.0  0.105557
# ...         ...    ...     ...   ...             ...          ...       ...
# 26243       0.0    0.3     1.0   0.2             0.0          0.0  0.105084
# 26244       0.0    0.3     1.0   0.2             0.0          0.0  0.105589
# 26245       0.0    0.3     1.0   0.2             0.0          0.0  0.106086
# 26246       0.0    0.3     1.0   0.2             0.0          0.0  0.105601
# 26247       0.0    0.3     1.0   0.2             0.0          0.0  0.105105
#
#        airspeed
# 0      0.000003
# 1      0.000003
# 2      0.000003
# 3      0.000003
# 4      0.000004
# ...         ...
# 26243  0.000227
# 26244  0.000198
# 26245  0.000186
# 26246  0.000196
# 26247  0.000192
#
# [26248 rows x 8 columns]

# %% [markdown]
# ## Entrada/Salida y perceptrón multicapa

# %%
inp = ["rpm", "airspeed", "throttle_input", "brake_input"]
out = ["throttle", "brake", "clutch", "gear", ]

X = datos_scaled[inp]
Y = datos_scaled[out]
mlp = MLPRegressor(hidden_layer_sizes=(256, 256, 256, 256, 256, 256), random_state=0, verbose=True)
mlp.fit(X, Y)
myx = pd.DataFrame(X.iloc[1000]).transpose()
display(mlp.predict(myx))
Y.iloc[1000]
# Out:
# Iteration 1, loss = 0.02111323
# Iteration 2, loss = 0.01531872
# Iteration 3, loss = 0.01469200
# Iteration 4, loss = 0.01432829
# Iteration 5, loss = 0.01399202
# Iteration 6, loss = 0.01385424
# Iteration 7, loss = 0.01371893
# Iteration 8, loss = 0.01342250
# Iteration 9, loss = 0.01326872
# Iteration 10, loss = 0.01309912
# Iteration 11, loss = 0.01298441
# Iteration 12, loss = 0.01246580
# Iteration 13, loss = 0.01216090
# Iteration 14, loss = 0.01206477
# Iteration 15, loss = 0.01180552
# Iteration 16, loss = 0.01163567
# Iteration 17, loss = 0.01139380
# Iteration 18, loss = 0.01119448
# Iteration 19, loss = 0.01113452
# Iteration 20, loss = 0.01112189
# Iteration 21, loss = 0.01072816
# Iteration 22, loss = 0.01105160
# Iteration 23, loss = 0.01083571
# Iteration 24, loss = 0.01031935
# Iteration 25, loss = 0.01026283
# Iteration 26, loss = 0.01054221
# Iteration 27, loss = 0.01032295
# Iteration 28, loss = 0.00980152
# Iteration 29, loss = 0.01006021
# Iteration 30, loss = 0.00985536
# Iteration 31, loss = 0.00949405
# Iteration 32, loss = 0.00973762
# Iteration 33, loss = 0.00958518
# Iteration 34, loss = 0.00915142
# Iteration 35, loss = 0.00965745
# Iteration 36, loss = 0.00966515
# Iteration 37, loss = 0.00906728
# Iteration 38, loss = 0.00924537
# Iteration 39, loss = 0.00926252
# Iteration 40, loss = 0.00899071
# Iteration 41, loss = 0.00885352
# Iteration 42, loss = 0.00895286
# Iteration 43, loss = 0.00866224
# Iteration 44, loss = 0.00934630
# Iteration 45, loss = 0.00907677
# Iteration 46, loss = 0.00891970
# Iteration 47, loss = 0.00880820
# Iteration 48, loss = 0.00867599
# Iteration 49, loss = 0.00841373
# Iteration 50, loss = 0.00874722
# Iteration 51, loss = 0.00896549
# Iteration 52, loss = 0.00837218
# Iteration 53, loss = 0.00849844
# Iteration 54, loss = 0.00832793
# Iteration 55, loss = 0.00822069
# Iteration 56, loss = 0.00838054
# Iteration 57, loss = 0.00827453
# Iteration 58, loss = 0.00818941
# Iteration 59, loss = 0.00861216
# Iteration 60, loss = 0.00883155
# Iteration 61, loss = 0.00810283
# Iteration 62, loss = 0.00799509
# Iteration 63, loss = 0.00832094
# Iteration 64, loss = 0.00818478
# Iteration 65, loss = 0.00824966
# Iteration 66, loss = 0.00820619
# Iteration 67, loss = 0.00795539
# Iteration 68, loss = 0.00821665
# Iteration 69, loss = 0.00860484
# Iteration 70, loss = 0.00803181
# Iteration 71, loss = 0.00779466
# Iteration 72, loss = 0.00780273
# Iteration 73, loss = 0.00789310
# Iteration 74, loss = 0.00776494
# Iteration 75, loss = 0.00785469
# Iteration 76, loss = 0.00789524
# Iteration 77, loss = 0.00805621
# Iteration 78, loss = 0.00741013
# Iteration 79, loss = 0.00781760
# Iteration 80, loss = 0.00760206
# Iteration 81, loss = 0.00760391
# Iteration 82, loss = 0.00752498
# Iteration 83, loss = 0.00763692
# Iteration 84, loss = 0.00750125
# Iteration 85, loss = 0.00767560
# Iteration 86, loss = 0.00775691
# Iteration 87, loss = 0.00752274
# Iteration 88, loss = 0.00736432
# Iteration 89, loss = 0.00760713
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# array([[ 0.03215958, -0.01171905,  0.1328    ,  0.58925992]])
# throttle    0.000000
# brake       0.000000
# clutch      0.037872
# gear        0.600000
# Name: 1000, dtype: float64

# %% [markdown]
# ## Verificación

# %%
bng_path = "C:\Program Files (x86)\Steam\steamapps\common\BeamNG.drive"
bng = BeamNGpy('localhost', 64256, home=bng_path)
bng.open()

# %%
scenario = Scenario('west_coast_usa', 'ml_beamng')
vehicle = Vehicle('veh', model='pessima', licence='HOLA')
electrics = Electrics()
vehicle.attach_sensor("electrics", electrics)
scenario.add_vehicle(vehicle, pos=(-717, 101, 118), rot_quat=(0, 0, 0.3826834, 0.9238795))
scenario.make(bng)
bng.load_scenario(scenario)
bng.start_scenario()
vehicle.set_shift_mode("realistic_manual")
# Out:
# ---------------------------------------------------------------------------
# BNGValueError                             Traceback (most recent call last)
# Cell In [6], line 9
#       7 bng.load_scenario(scenario)
#       8 bng.start_scenario()
# ----> 9 vehicle.set_shift_mode("realistic")
#
# File ~\miniconda3\lib\site-packages\beamngpy\beamngcommon.py:146, in ack.<locals>.ack_wrapper.<locals>.ack_wrapped(*args, **kwargs)
#     144 @wraps(fun)
#     145 def ack_wrapped(*args, **kwargs):
# --> 146     ret = fun(*args, **kwargs)
#     147     resp = args[0].connection.recv()
#     148     if resp['type'] != ack_type:
#
# File ~\miniconda3\lib\site-packages\beamngpy\vehicle.py:291, in Vehicle.set_shift_mode(self, mode)
#     289 mode = mode.lower().strip()
#     290 if mode not in SHIFT_MODES:
# --> 291     raise BNGValueError(f'Non-existent shift mode: {mode}')
#     293 mode = SHIFT_MODES[mode]
#     294 data = dict(type='SetShiftMode')
#
# BNGValueError: Non-existent shift mode: realistic

# %%
oldspeed = 0
oldgear = 0
def lectura_sensores():
    global oldspeed
    global oldgear
    # LECTURA
    vehicle.poll_sensors()
    electrics.data.pop("wheelThermals")            
    x = pd.DataFrame(electrics.data.values(), index=electrics.data.keys()).transpose()
    x = x[columnas]
    # MANTENER CAMBIO
    if electrics.data["is_shifting"]:
        if electrics.data["gear"] == 0:
            x.at[0, "gear"] = oldgear
    else:
        oldgear = electrics.data["gear"]
    # ACELERACIÓN
    """
    curspeed = x["airspeed"].iloc[0]
    x["accel"] = curspeed - oldspeed
    oldspeed = curspeed
    """
    return x

oldtime = 0
while True:
    cmd1 = 0
    cmd2 = 0
    if (keyboard.is_pressed('D')):
        break
    elif (keyboard.is_pressed('W')):
        cmd1 = 0.7
        cmd2 = 0
    elif (keyboard.is_pressed('S')):
        cmd1 = 0
        cmd2 = 0.5
    #actualizar valor
    curtime = millis()
    if curtime > (oldtime + step):
        oldtime = curtime
        x = lectura_sensores()
        x["throttle_input"] = cmd1
        x["brake_input"] = cmd2
        #x["cmd"] = stateToCmd(x)
        #"""
        x_scaled = pd.DataFrame(scaler.transform(x), index=x.index, columns=x.columns)
        output = dict(zip(out, mlp.predict(x_scaled[inp]).tolist()[0]))
        vehicle.control(
            throttle=output["throttle"],
            brake=output["brake"],
            clutch=output["clutch"],
            gear=round(output["gear"]*5)
        )
        display(output)
        #"""
        #display(x.transpose())
        clear_output(wait = True)
# Out:
# {'throttle': 0.007077667959245942,
#  'brake': 0.20171296063171246,
#  'clutch': 0.994310056479737,
#  'gear': 0.10347142413222406}

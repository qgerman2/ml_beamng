# %%
from pathlib import Path
import pandas as pd
import numpy as np
from io import StringIO
from sklearn.preprocessing import MaxAbsScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from IPython.display import clear_output
from beamngpy import BeamNGpy, Scenario, Vehicle
from beamngpy.sensors import Electrics
import keyboard
import time

def millis():
    return time.time_ns() / 1000000
oldtime = millis()
curtime = 0
rectime = 0
step = 1/60 * 1000 #60 hz

# %% [markdown]
# ## Lectura de datos

# %%
# Leer carpeta
CARPETA = "datos_beamng"
datos = False
columnas = [
    # Comandos
    "throttle",
    "brake",
    "clutch",
    "gear",
    # Estado
    "throttle_input",
    "brake_input",
    "rpm",
    "airspeed"
]
files = Path(CARPETA).glob('*')
for i, ruta in enumerate(files):
    df = pd.read_csv(ruta, usecols=columnas + ["is_shifting"])
    if (i == 0):
        datos = df
    else:
        datos = pd.concat([datos, df], ignore_index=True)
# MANTENER CAMBIO
gear = 0
for i in range(datos.shape[0]):
    if (datos["is_shifting"].iloc[i] == True):
        if (datos["gear"].iloc[i] == 0):
            datos.at[i, "gear"] = gear
    else:
        gear = datos["gear"].iloc[i]
datos.drop(columns="is_shifting", inplace=True)
datos = datos[columnas]
display(datos)
# Out:
#        throttle  brake  clutch  gear  throttle_input  brake_input         rpm  \
# 0           0.0    0.3     1.0   1.0             0.0          0.0  677.650753
# 1           0.0    0.3     1.0   1.0             0.0          0.0  674.418942
# 2           0.0    0.3     1.0   1.0             0.0          0.0  677.589228
# 3           0.0    0.3     1.0   1.0             0.0          0.0  680.929954
# 4           0.0    0.3     1.0   1.0             0.0          0.0  677.760520
# ...         ...    ...     ...   ...             ...          ...         ...
# 26243       0.0    0.3     1.0   1.0             0.0          0.0  674.727744
# 26244       0.0    0.3     1.0   1.0             0.0          0.0  677.971016
# 26245       0.0    0.3     1.0   1.0             0.0          0.0  681.158786
# 26246       0.0    0.3     1.0   1.0             0.0          0.0  678.049100
# 26247       0.0    0.3     1.0   1.0             0.0          0.0  674.860924
#
#        airspeed
# 0      0.000130
# 1      0.000126
# 2      0.000147
# 3      0.000171
# 4      0.000180
# ...         ...
# 26243  0.011388
# 26244  0.009939
# 26245  0.009315
# 26246  0.009805
# 26247  0.009637
#
# [26248 rows x 8 columns]

# %% [markdown]
# ## Normalizar

# %%
scaler = MaxAbsScaler().fit(datos)
datos_scaled = pd.DataFrame(scaler.transform(datos), index=datos.index, columns=datos.columns)

# %% [markdown]
# ## Entrada/Salida y perceptrón multicapa

# %%
inp = ["rpm", "airspeed", "throttle_input", "brake_input"]
out = ["throttle", "brake", "clutch", "gear", ]

X = datos_scaled[inp]
Y = datos_scaled[out]
mlp = MLPRegressor(
    hidden_layer_sizes=(256, 256, 256, 256, 256, 256),
    verbose=True)
mlp.fit(X, Y)
# Out:
# Iteration 1, loss = 0.02094680
# Iteration 2, loss = 0.01529557
# Iteration 3, loss = 0.01470803
# Iteration 4, loss = 0.01440890
# Iteration 5, loss = 0.01409677
# Iteration 6, loss = 0.01383268
# Iteration 7, loss = 0.01365778
# Iteration 8, loss = 0.01348983
# Iteration 9, loss = 0.01328512
# Iteration 10, loss = 0.01308330
# Iteration 11, loss = 0.01271826
# Iteration 12, loss = 0.01255753
# Iteration 13, loss = 0.01225385
# Iteration 14, loss = 0.01196533
# Iteration 15, loss = 0.01182142
# Iteration 16, loss = 0.01153632
# Iteration 17, loss = 0.01148571
# Iteration 18, loss = 0.01137565
# Iteration 19, loss = 0.01111706
# Iteration 20, loss = 0.01090185
# Iteration 21, loss = 0.01116427
# Iteration 22, loss = 0.01067649
# Iteration 23, loss = 0.01042254
# Iteration 24, loss = 0.01061244
# Iteration 25, loss = 0.01010329
# Iteration 26, loss = 0.01005747
# Iteration 27, loss = 0.01040174
# Iteration 28, loss = 0.00973634
# Iteration 29, loss = 0.00987345
# Iteration 30, loss = 0.00978162
# Iteration 31, loss = 0.00953814
# Iteration 32, loss = 0.00990697
# Iteration 33, loss = 0.00975647
# Iteration 34, loss = 0.00944790
# Iteration 35, loss = 0.00938423
# Iteration 36, loss = 0.00950195
# Iteration 37, loss = 0.00906227
# Iteration 38, loss = 0.00959887
# Iteration 39, loss = 0.00915077
# Iteration 40, loss = 0.00913329
# Iteration 41, loss = 0.00917686
# Iteration 42, loss = 0.00998884
# Iteration 43, loss = 0.00913409
# Iteration 44, loss = 0.00891006
# Iteration 45, loss = 0.00880875
# Iteration 46, loss = 0.00926642
# Iteration 47, loss = 0.00874504
# Iteration 48, loss = 0.00879049
# Iteration 49, loss = 0.00866267
# Iteration 50, loss = 0.00868262
# Iteration 51, loss = 0.00902298
# Iteration 52, loss = 0.00883813
# Iteration 53, loss = 0.00839027
# Iteration 54, loss = 0.00841786
# Iteration 55, loss = 0.00885354
# Iteration 56, loss = 0.00829174
# Iteration 57, loss = 0.00851843
# Iteration 58, loss = 0.00858282
# Iteration 59, loss = 0.00829053
# Iteration 60, loss = 0.00822636
# Iteration 61, loss = 0.00810787
# Iteration 62, loss = 0.00838741
# Iteration 63, loss = 0.00810231
# Iteration 64, loss = 0.00804683
# Iteration 65, loss = 0.00789230
# Iteration 66, loss = 0.00810633
# Iteration 67, loss = 0.00797395
# Iteration 68, loss = 0.00843489
# Iteration 69, loss = 0.00817108
# Iteration 70, loss = 0.00794543
# Iteration 71, loss = 0.00858236
# Iteration 72, loss = 0.00806856
# Iteration 73, loss = 0.00789501
# Iteration 74, loss = 0.00780742
# Iteration 75, loss = 0.00822065
# Iteration 76, loss = 0.00761689
# Iteration 77, loss = 0.00802944
# Iteration 78, loss = 0.00785179
# Iteration 79, loss = 0.00794186
# Iteration 80, loss = 0.00826003
# Iteration 81, loss = 0.00790974
# Iteration 82, loss = 0.00769415
# Iteration 83, loss = 0.00790500
# Iteration 84, loss = 0.00744522
# Iteration 85, loss = 0.00780008
# Iteration 86, loss = 0.00741183
# Iteration 87, loss = 0.00754211
# Iteration 88, loss = 0.00769963
# Iteration 89, loss = 0.00799102
# Iteration 90, loss = 0.00757648
# Iteration 91, loss = 0.00757668
# Iteration 92, loss = 0.00707974
# Iteration 93, loss = 0.00747882
# Iteration 94, loss = 0.00764429
# Iteration 95, loss = 0.00736136
# Iteration 96, loss = 0.00771362
# Iteration 97, loss = 0.00768035
# Iteration 98, loss = 0.00745539
# Iteration 99, loss = 0.00774398
# Iteration 100, loss = 0.00750274
# Iteration 101, loss = 0.00735075
# Iteration 102, loss = 0.00715565
# Iteration 103, loss = 0.00757505
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(hidden_layer_sizes=(256, 256, 256, 256, 256, 256), verbose=True)

# %% [markdown]
# ## Verificación

# %%
bng_path = "C:\Program Files (x86)\Steam\steamapps\common\BeamNG.drive"
bng = BeamNGpy('localhost', 64256, home=bng_path)
bng.open()

# %%
scenario = Scenario('west_coast_usa', 'ml_beamng')
vehicle = Vehicle('veh', model='pessima', licence='HOLA')
electrics = Electrics()
vehicle.attach_sensor("electrics", electrics)
scenario.add_vehicle(vehicle, pos=(-717, 101, 118), rot_quat=(0, 0, 0.3826834, 0.9238795))
scenario.make(bng)
bng.load_scenario(scenario)
bng.start_scenario()
vehicle.set_shift_mode("realistic_manual")

# %%
oldspeed = 0
oldgear = 0
def lectura_sensores():
    global oldspeed
    global oldgear
    # LECTURA
    vehicle.poll_sensors()
    electrics.data.pop("wheelThermals")            
    x = pd.DataFrame(electrics.data.values(), index=electrics.data.keys()).transpose()
    x = x[columnas]
    # MANTENER CAMBIO
    if electrics.data["is_shifting"]:
        if electrics.data["gear"] == 0:
            x.at[0, "gear"] = oldgear
    else:
        oldgear = electrics.data["gear"]
    return x

oldtime = 0
while True:
    cmd1 = 0
    cmd2 = 0
    if (keyboard.is_pressed('D')):
        break
    elif (keyboard.is_pressed('W')):
        cmd1 = 0.7
        cmd2 = 0
    elif (keyboard.is_pressed('S')):
        cmd1 = 0
        cmd2 = 0.5
    #actualizar valor
    curtime = millis()
    if curtime > (oldtime + step):
        oldtime = curtime
        x = lectura_sensores()
        x["throttle_input"] = cmd1
        x["brake_input"] = cmd2
        x_scaled = pd.DataFrame(scaler.transform(x), index=x.index, columns=x.columns)
        output = dict(zip(out, mlp.predict(x_scaled[inp]).tolist()[0]))
        vehicle.control(
            throttle=output["throttle"],
            brake=output["brake"],
            clutch=output["clutch"],
            gear=round(output["gear"]*5)
        )
        display(output)
        clear_output(wait = True)
# Out:
# {'throttle': 0.35124755162588656,
#  'brake': 0.006242211517956953,
#  'clutch': 0.37474610084180693,
#  'gear': 0.15613829520873826}
